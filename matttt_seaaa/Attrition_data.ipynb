# %%
import pandas as pd

# %%
df=pd.read_csv("Attrition_dataset.csv")
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %%
# to find the no of records and columns in a DataFrame
df.shape
# Out:
# (49653, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %% [markdown]
# Before cleaning we have to extract
# info is used to check for nul values

# %% [markdown]
# ## **CLEANING**

# %% [markdown]
# -> Cheking for null values
#
# -> Checking duplicates --------duplicated() -> False ------> no duplicated records( it checks rows)
#
#                                duplicated(subset='')---> True-->duplicate records

# %%
df.duplicated(subset='EmployeeID').any()

# df=df.duplicated(subset='EmployeeID')
# Out:
# np.True_

# %% [markdown]
# # Drop the Duplicates

# %%
# df.drop_duplicates(subset='EmployeeID')

#to keep latest updated records
df=df.drop_duplicates(subset='EmployeeID',keep='last')

# %%
df.shape
# Out:
# (6284, 18)

# %%
# Convert the object datatype into date format
col=['recorddate_key','birthdate_key','orighiredate_key','terminationdate_key']
for i in col:
    df[i]=pd.to_datetime(df[i])
# Out:
# C:\Users\Muskan\AppData\Local\Temp\ipykernel_12184\2753947107.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=pd.to_datetime(df[i])
# C:\Users\Muskan\AppData\Local\Temp\ipykernel_12184\2753947107.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=pd.to_datetime(df[i])
# C:\Users\Muskan\AppData\Local\Temp\ipykernel_12184\2753947107.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6284 entries, 9 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           6284 non-null   int64
#  1   recorddate_key       6284 non-null   datetime64[ns]
#  2   birthdate_key        6284 non-null   datetime64[ns]
#  3   orighiredate_key     6284 non-null   datetime64[ns]
#  4   terminationdate_key  6284 non-null   datetime64[ns]
#  5   age                  6284 non-null   int64
#  6   length_of_service    6284 non-null   int64
#  7   city_name            6284 non-null   object
#  8   department_name      6284 non-null   object
#  9   job_title            6284 non-null   object
#  10  store_name           6284 non-null   int64
#  11  gender_short         6284 non-null   object
#  12  gender_full          6284 non-null   object
#  13  termreason_desc      6284 non-null   object
# ...

# %%
df=df.reset_index(drop=True)

# %%
df=df.drop(columns=['store_name','gender_short'])

# %% [markdown]
# ## Rename the columns

# %%
# df.columns()


col_list=['EMP_ID','Record_date','DOB','Hiredate','Term_Date','Age','Experience','City','Dname','JOB','Gender','Term_reason','term Type','Year','Status', 'Business_unit']
df.columns=col_list
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %%
df['Status']=df['Status'].str.title()
df['Business_unit']=df['Business_unit'].str.title()

# %%
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %%
## to create the age category
# check for starting age

# use the min and max
df[['Age','Experience']].agg(['min','max'])
# Out:
#      Age  Experience
# min   19           0
# max   65          26

# %%
# age columns are numerical column, with continuous range use-----------> cut function
# 18-25 range , 18 excluded, 25 included, 

df['Age_category']=pd.cut(df['Age'], bins=[18,25,59,65],labels=['Teen','Adult','Senior'])
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %% [markdown]
# Creating new column service category based on experience

# %%
df['Service Category']=pd.cut(df['Experience'],bins=[-1,1,5,26],labels=['Freshers','Senior','Experts'])
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %%
df['Dname'].unique()
# Out:
# array(['Executive', 'Store Management', 'Meats', 'Recruitment',
#        'Customer Service', 'Produce', 'Bakery', 'Dairy',
#        'Processed Foods', 'Training', 'Labor Relations', 'HR Technology',
#        'Employee Records', 'Compensation', 'Legal',
#        'Accounts Receiveable', 'Information Technology',
#        'Accounts Payable', 'Audit', 'Accounting', 'Investment'],
#       dtype=object)

# %%
df['JOB'].unique()
# Out:
# array(['CEO', 'VP Stores', 'Legal Counsel', 'VP Human Resources',
#        'VP Finance', 'Exec Assistant, VP Stores',
#        'Exec Assistant, Legal Counsel', 'CHief Information Officer',
#        'Store Manager', 'Meats Manager',
#        'Exec Assistant, Human Resources', 'Exec Assistant, Finance',
#        'Director, Recruitment', 'Meat Cutter', 'Customer Service Manager',
#        'Produce Manager', 'Bakery Manager', 'Dairy Person',
#        'Processed Foods Manager', 'Produce Clerk', 'Baker',
#        'Shelf Stocker', 'Cashier', 'Director, Training',
#        'Director, Labor Relations', 'Director, HR Technology',
#        'Director, Employee Records', 'Director, Compensation',
#        'Corporate Lawyer', 'Director, Accounts Receivable',
#        'Systems Analyst', 'Director, Accounts Payable', 'Director, Audit',
#        'Director, Accounting', 'Director, Investments', 'Recruiter',
#        'Trainer', 'Labor Relations Analyst', 'Dairy Manager',
# ...

# %% [markdown]
# ## apply

# %%
def job_clean(row):
    j=row['JOB']
    d=row['Dname']
    if j!='Auditor' and j!='Dairy Person':
        if d in j:
            return j.replace(d,'').strip(',').strip(',s')
        else:
            return j.removeprefix('Exec Assistant').strip(',v')
        

## strip is used to remove the end values

# %%
df['JOB']=df.apply(job_clean,axis=1)


df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %%
df['JOB'].unique()
# Out:
# array(['CEO', 'VP Stores', 'Legal Counsel', 'VP Human Resources',
#        'VP Finance', ' VP Stores', ' Legal Counsel',
#        'CHief Information Officer', 'Store Manager', ' Manager',
#        ' Human Resources', ' Finance', 'Director, ', 'Meat Cutter', None,
#        ' Clerk', 'Baker', 'Shelf Stocker', 'Cashier', 'Corporate Lawyer',
#        'Director, Accounts Receivable', 'Systems Analyst', 'Recruiter',
#        'Trainer', ' Analyst', 'HRIS Analyst', 'Benefits Admin'],
#       dtype=object)

# %%
df['JOB']=df['JOB'].replace('CHief Information Officer','Chief Information Officer')

# %%
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %% [markdown]
# ## **Check how many peoples are active**
#
# ->>>> use **loc[]** method
#
# ->> record on which date it has recored.........

# %%
df.loc[df['Status']=='Active','Record_date'].unique()
# Out:
# <DatetimeArray>
# ['2015-12-31 00:00:00']
# Length: 1, dtype: datetime64[ns]

# %% [markdown]
# ->> check weather the active members has termination date
#
# ->> unique is used

# %%
df.loc[df['Status']=='Active','Term_Date'].unique()
# Out:
# <DatetimeArray>
# ['1900-01-01 00:00:00']
# Length: 1, dtype: datetime64[ns]

# %% [markdown]
# active people should nothave he termination date so replace Term_Date-->

# %%
df.loc[df['Status']=='Active','Term_Date']='2015-12-31'

# %%
df.loc[df['Status']=='Active']
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 4794    8332  2015-12-31 1994-12-20 2013-12-05 2015-12-31   21           2
# 4795    8333  2015-12-31 1994-12-19 2013-12-05 2015-12-31   21           2
# 4796    8334  2015-12-31 1994-12-27 2013-12-09 2015-12-31   21           2
# 4797    8335  2015-12-31 1994-12-28 2013-12-10 2015-12-31   21           2
# 4798    8336  2015-12-31 1994-12-31 2013-12-11 2015-12-31   21           2
#
# ...

# %% [markdown]
# ## **Display the count of employess hired in each year**

# %%
df['Hiredate']
# Out:
# 0      1989-08-28
# 1      1989-08-28
# 2      1989-08-28
# 3      1989-08-28
# 4      1989-08-31
#           ...
# 6279   2013-08-19
# 6280   2013-08-27
# 6281   2013-09-15
# 6282   2013-10-09
# 6283   2013-11-24
# Name: Hiredate, Length: 6284, dtype: datetime64[ns]

# %% [markdown]
# reset_index -> to convert into table(DatafRame)

# %%
h_df=df['Hiredate'].dt.year.value_counts().sort_values().reset_index()
h_df
# Out:
#     Hiredate  count
# 0       1989     86
# 1       1991    200
# 2       2001    212
# 3       1990    214
# 4       2004    214
# 5       2003    218
# 6       2013    218
# 7       2007    237
# 8       2002    238
# 9       2006    239
# 10      2011    242
# 11      2008    246
# 12      1992    248
# 13      2009    249
# 14      2010    254
# 15      2005    256
# 16      2012    259
# 17      1996    273
# 18      1994    298
# 19      1993    298
# 20      2000    305
# 21      1995    312
# 22      1997    312
# 23      1999    315
# 24      1998    341

# %%
h_df.columns=['Year','No_of_hirings']
h_df
# Out:
#     Year  No_of_hirings
# 0   1989             86
# 1   1991            200
# 2   2001            212
# 3   1990            214
# 4   2004            214
# 5   2003            218
# 6   2013            218
# 7   2007            237
# 8   2002            238
# 9   2006            239
# 10  2011            242
# 11  2008            246
# 12  1992            248
# 13  2009            249
# 14  2010            254
# 15  2005            256
# 16  2012            259
# 17  1996            273
# 18  1994            298
# 19  1993            298
# 20  2000            305
# 21  1995            312
# 22  1997            312
# 23  1999            315
# 24  1998            341

# %% [markdown]
# ## **Display the termination details**
#
# filter the termination details

# %%
t_df=df.loc[df['Status']=='Terminated','Term_Date'].dt.year.value_counts().sort_values().reset_index()
t_df.columns=['Year','No_of_Terminations']
t_df
# Out:
#    Year  No_of_Terminations
# 0  2013                 105
# 1  2011                 110
# 2  2010                 123
# 3  2012                 130
# 4  2006                 134
# 5  2009                 142
# 6  2015                 162
# 7  2007                 162
# 8  2008                 164
# 9  2014                 253

# %% [markdown]
# ## Merge both the tables

# %% [markdown]
# on: based on which column we are merging
#
# how:it is used for join contion( )
#
#         Why Full Outer join?
#
#         why not inner join?
#              some of the year does not have termination, it will some some values

# %%
pd.merge(h_df,t_df,on='Year',how='outer')
# Out:
#     Year  No_of_hirings  No_of_Terminations
# 0   1989           86.0                 NaN
# 1   1990          214.0                 NaN
# 2   1991          200.0                 NaN
# 3   1992          248.0                 NaN
# 4   1993          298.0                 NaN
# 5   1994          298.0                 NaN
# 6   1995          312.0                 NaN
# 7   1996          273.0                 NaN
# 8   1997          312.0                 NaN
# 9   1998          341.0                 NaN
# 10  1999          315.0                 NaN
# 11  2000          305.0                 NaN
# 12  2001          212.0                 NaN
# 13  2002          238.0                 NaN
# 14  2003          218.0                 NaN
# 15  2004          214.0                 NaN
# 16  2005          256.0                 NaN
# 17  2006          239.0               134.0
# 18  2007          237.0               162.0
# 19  2008          246.0               164.0
# ...

# %%
df1=pd.merge(h_df,t_df,on='Year',how='outer').fillna(0).astype(int)
df1
# Out:
#     Year  No_of_hirings  No_of_Terminations
# 0   1989             86                   0
# 1   1990            214                   0
# 2   1991            200                   0
# 3   1992            248                   0
# 4   1993            298                   0
# 5   1994            298                   0
# 6   1995            312                   0
# 7   1996            273                   0
# 8   1997            312                   0
# 9   1998            341                   0
# 10  1999            315                   0
# 11  2000            305                   0
# 12  2001            212                   0
# 13  2002            238                   0
# 14  2003            218                   0
# 15  2004            214                   0
# 16  2005            256                   0
# 17  2006            239                 134
# 18  2007            237                 162
# 19  2008            246                 164
# ...

# %%
df1['Retention1']=df1['No_of_hirings']-df1['No_of_Terminations']
df1
# Out:
#     Year  No_of_hirings  No_of_Terminations  Retention1
# 0   1989             86                   0          86
# 1   1990            214                   0         214
# 2   1991            200                   0         200
# 3   1992            248                   0         248
# 4   1993            298                   0         298
# 5   1994            298                   0         298
# 6   1995            312                   0         312
# 7   1996            273                   0         273
# 8   1997            312                   0         312
# 9   1998            341                   0         341
# 10  1999            315                   0         315
# 11  2000            305                   0         305
# 12  2001            212                   0         212
# 13  2002            238                   0         238
# 14  2003            218                   0         218
# 15  2004            214                   0         214
# ...

# %%
df1['Retention']=df1['Retention1'].cumsum()
df1=df1.drop(columns='Retention1')
df1
# Out:
#     Year  No_of_hirings  No_of_Terminations  Retention
# 0   1989             86                   0         86
# 1   1990            214                   0        300
# 2   1991            200                   0        500
# 3   1992            248                   0        748
# 4   1993            298                   0       1046
# 5   1994            298                   0       1344
# 6   1995            312                   0       1656
# 7   1996            273                   0       1929
# 8   1997            312                   0       2241
# 9   1998            341                   0       2582
# 10  1999            315                   0       2897
# 11  2000            305                   0       3202
# 12  2001            212                   0       3414
# 13  2002            238                   0       3652
# 14  2003            218                   0       3870
# 15  2004            214                   0       4084
# ...

# %%
df.loc[df['Status']=='Active'].shape
# Out:
# (4799, 18)

# %% [markdown]
# ## **Cumulative SUM**

# %% [markdown]
# Therefore,
#
# it displays the no of employess hired in each year, and who are active
#
# Hence the data is correct

# %%
df1['Retention']=df1['Retention'].cumsum()

# %%
df1=df1.drop(columns='Retention')
df1
# Out:
#     Year  No_of_hirings  No_of_Terminations
# 0   1989             86                   0
# 1   1990            214                   0
# 2   1991            200                   0
# 3   1992            248                   0
# 4   1993            298                   0
# 5   1994            298                   0
# 6   1995            312                   0
# 7   1996            273                   0
# 8   1997            312                   0
# 9   1998            341                   0
# 10  1999            315                   0
# 11  2000            305                   0
# 12  2001            212                   0
# 13  2002            238                   0
# 14  2003            218                   0
# 15  2004            214                   0
# 16  2005            256                   0
# 17  2006            239                 134
# 18  2007            237                 162
# 19  2008            246                 164
# ...

# %% [markdown]
# # Shape returns the number of columns and rows

# %%
df.loc[df['Status']=='Active'].shape
# Out:
# (4799, 18)

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(3,4))
sns.countplot(df,x='Status')
plt.title('Distribution of meps according to status')
plt.ylabel('No of Employees')
plt.show()

# %% [markdown]
# **Observation**--most of emps are active compared to terminated

# %%
c=df['Gender'].value_counts()
c.values
c.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=c.values,labels=c.index,autopct='%.1f%%')
plt.title('Distribution of Emp Gender wise')
plt.show()

# %% [markdown]
# **observation**--The workforce is balanced with slight maority female , than the male

# %%
plt.figure(figsize=(4,5))
b=sns.barplot(df,x='Status',y='Experience',errorbar=None,hue="Gender",palette=['cyan','grey'])
for i in b.containers:
    b.bar_label(i,fmt='%.1f',padding=-19)
plt.yticks(range(0,15,2))
plt.legend(loc='best',ncol=2,title='gender')
plt.title("Avg Experience of emps Gender wise")
plt.show()

# %%
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %%
df1.head()
# Out:
#    Year  No_of_hirings  No_of_Terminations
# 0  1989             86                   0
# 1  1990            214                   0
# 2  1991            200                   0
# 3  1992            248                   0
# 4  1993            298                   0

# %%
plt.figure(figsize=(7,6))
sns.lineplot(df1,x='Year',y='No_of_hirings', label='hiring')      #label is box which identify colour
sns.lineplot(df1,x='Year',y='No_of_Terminations', label='attrition')
plt.title('Trend of Hiring and Termination in an Organization')
plt.xticks(range(1989,2016),rotation=70)        #rotation--->to rotate the ranges
plt.grid()     #to get lines inside graph
plt.show()

# %% [markdown]
# **Observtion**:
#
# Highest hiring occured at 1998,
# while the Highest attrition occured in 2014

# %%
plt.figure(figsize=(6,5))
e=sns.lineplot(df1,x='Year',y='Retention',linestyle='-.',marker='d',markersize=10,markerfacecolor='blue',color='purple')             #continueous data so line plot
e.set_facecolor('skyblue')
plt.xticks(range(1988,2016),rotation=70)                       #marker=s-->square,0->circle,^-->triangle,d-->diamond,p-->pentagon,h-->hexagon
plt.title('retention trend over a year')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 plt.figure(figsize=(6,5))
# ----> 2 e=sns.lineplot(df1,x='Year',y='Retention',linestyle='-.',marker='d',markersize=10,markerfacecolor='blue',color='purple')             #continueous data so line plot
#       3 e.set_facecolor('skyblue')
#       4 plt.xticks(range(1988,2016),rotation=70)                       #marker=s-->square,0->circle,^-->triangle,d-->diamond,p-->pentagon,h-->hexagon
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
# ...

# %%
t=df.loc[df['Status']=='Terminated']
tt=t['term Type'].value_counts()
tr=t['Term_reason'].value_counts()
# Out:
# Term_reason
# Retirement    885
# Resignaton    385
# Layoff        215
# Name: count, dtype: int64

# %%
'''termination analysis based on term type and term reason
2 pie
-term type and -term reason in one page
in matrix type 2 col and single row(nrows=1,ncols=2)
pie chart-->percentage so make value counts


'''
# Out:
# 'termination analysis based on term type and term reason\n2 pie\n-term type and -term reason in one page\nin matrix type 2 col and single row(nrows=1,ncols=2)\npie chart-->percentage so make value counts\n\n\n'

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
plt.suptitle('Termination Analysis')     #subtitle means main heading

axes[0].pie(x=tt.values,labels=tt.index,autopct='%.1f%%')
axes[0].set_title('Proportion of emp by Term Type')         #set_title means sub heading

axes[1].pie(x=tr.values,labels=tr.index,autopct='%.1f%%')
axes[1].set_title('Proportion of emp by Term Reason')

plt.tight_layout()    #not to overlap
plt.show()

# %% [markdown]
# **Observation**--most of the emps exit voluntarily(85.5%) due to Retirement or Resignation
# while other exit invouluntary due to layoff

# %%
df
# Out:
#       EMP_ID Record_date        DOB   Hiredate  Term_Date  Age  Experience  \
# 0       1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61          26
# 1       1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58          26
# 2       1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60          26
# 3       1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56          26
# 4       1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57          26
# ...      ...         ...        ...        ...        ...  ...         ...
# 6279    8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280    8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281    8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282    8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283    8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              City             Dname                 JOB  Gender  \
# ...

# %%
sc=df['Service Category'].value_counts()
# Out:
# Service Category
# Experts     5171
# Senior       946
# Freshers     167
# Name: count, dtype: int64

# %%
#category--countplot(serivce category col)  so we take facetgrid

fg=sns.FacetGrid(df,col='Gender',aspect=1.5)    #double the width axpect=2
fg.map_dataframe(sns.countplot,x='Service Category',hue='Status',palette='coolwarm',hue_order=['Terminated','Active'])                        #plot in face grid   #huw is to change le loc from 1st to lastt in color
plt.legend()     #to get box of each colour identification
plt.suptitle('Distribution of Service category',y=1.5)    #y=1.5 to make hedidng top


plt.tight_layout()
plt.show()

# %% [markdown]
# Distribution of service category based on gender male are more

# %%
plt.figure(figsize=(8,4))
a=sns.histplot(data=df,x='Experience')
a.bar_label(a.containers[0])
plt.xticks(ticks=range(0,30,2))
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=df,x='Experience')
plt.xticks(range(0,28))
plt.grid()
plt.show()

# %% [markdown]
# highest dense occur in year 13

# %%
import numpy as np

# %%
plt.figure(figsize=(10,8))
a=sns.histplot(data=df,x='Age',kde=True,color='green')
plt.title("emps are distribution in an organization")
a.bar_label(a.containers[0])     #to get values of box
plt.xticks(ticks=np.linspace(19,65,18))
plt.show()

# %%
plt.figure(figsize=(17,5))
sns.kdeplot(data=df,x='Age',color='purple',fill=True)
plt.xticks(ticks=range(18,70))
plt.grid()
plt.show()

# %% [markdown]
# high dense occur at age 61-62

# %%
sns.scatterplot(df,x='Age',y='Experience',color='green')
# Out:
# <Axes: xlabel='Age', ylabel='Experience'>

# %%
df.corr(numeric_only=True)
# Out:
#               EMP_ID       Age  Experience      Year
# EMP_ID      1.000000 -0.946295   -0.928050  0.225236
# Age        -0.946295  1.000000    0.849308 -0.338389
# Experience -0.928050  0.849308    1.000000  0.137111
# Year        0.225236 -0.338389    0.137111  1.000000

# %%
sns.jointplot(df[['Age','Experience']])

# %%
a=df.corr(numeric_only=True)
sns.heatmap(a,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)    #visual representation of heatmap
l=plt.legend()
# Out:
# C:\Users\Muskan\AppData\Local\Temp\ipykernel_12184\4002749893.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   l=plt.legend()

# %%
 #to identify outliers(data points far away from majority of data) & Distribution(spread of data)
                    #-->univariant & bivariant plot

l=plt.legend()
# Out:
# C:\Users\Muskan\AppData\Local\Temp\ipykernel_12184\2176019521.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   l=plt.legend()
